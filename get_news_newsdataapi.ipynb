# %%
# !pip install newsdataapi
import newsdataapi 
import pandas as pd
import requests 
from newsdataapi import NewsDataApiClient
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
api_key='pub_138637c7854080d92fef0a433ed9d43bb4804'
api=NewsDataApiClient(apikey=api_key)
topic=input("write what you searching : ")
tech_news = api.news_api(language='en',q=topic,category="technology,business,science")
print(tech_news)
results=tech_news['results']
df=pd.DataFrame.from_dict(results)
df_new=df[['title','link']]
df_new.head()
# Out:
# write what you searching : AI
# ...

# %%
# Out:
#                                                title  \
# 0  The best Black Friday tech deals for 2022: dis...
# 1  Meta's new AI can beat human players at Diplomacy
# 2  The best Black Friday Apple deals on iPads, Ma...
# 3  The sheer scale of Microsoft Teams dominance c...
# 4  The best Black Friday robot vacuum and smart h...
#
#                                                 link
# 0  https://www.engadget.com/best-black-friday-tec...
# 1  https://www.rockpapershotgun.com/metas-new-ai-...
# 2  https://www.engadget.com/best-black-friday-app...
# 3  https://www.techradar.com/news/the-sheer-scale...
# 4  https://www.engadget.com/the-best-black-friday...
